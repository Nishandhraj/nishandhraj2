# %% [markdown]
# <span class="paper-toast-extra"></span> <span
# class="paper-toast-extra"></span>
#
# Google Account
#
# Nishandhraj
#
# nishanthraj788@gmail.com
#
#
# This notebook is open with private outputs. Outputs will not be saved.
# You can disable this in <a
# href="https://colab.research.google.com/drive/1OXNfAUrzI8nKxFfGXuC3tNgbEyy073XN#"
# id="private-outputs-notebook-info-link"
# data-command="notebook-settings">Notebook settings</a>
#
# Open notebook settings
#
# .
#
# <a
# href="https://drive.google.com/drive/search?q=owner%3Ame%20(type%3Aapplication%2Fvnd.google.colaboratory%20%7C%7C%20type%3Aapplication%2Fvnd.google.colab)&amp;authuser=0"
# aria-label="View in Google Drive"></a>
#
#
# NISHANDHRAJ PYTHON_PROJECT.ipynbS\_
#
# Notebook unstarred
#
# Star notebook in Google Drive
#
# File
#
#
#
# Edit
#
#
#
# View
#
#
#
# Insert
#
#
#
# Runtime
#
#
#
# Tools
#
#
#
# Help
#
#
#
# All changes saved
#
# Comment
#
# Open comments pane
#
# Share
#
# Share notebook
#
# Open settings
#
# <a
# href="https://accounts.google.com/SignOutOptions?hl=en&amp;continue=https://colab.research.google.com/drive/1OXNfAUrzI8nKxFfGXuC3tNgbEyy073XN"
# class="gb_e gb_1a gb_s" aria-label="Google Account: sree ram
# (sreeramgk.24@gmail.com)" role="button" tabindex="0"><span
# class="image placeholder gb_h gbii"
# data-original-image-src="./AKILAN.S%20PYTHON_PROJECT.ipynb%20-%20Colaboratory_files/unnamed.png"
# data-original-image-title=""
# srcset="https://lh3.googleusercontent.com/ogw/AAEL6shhTgbUK8gCKa3E_ZOFS-qwiSmVX1AKUFUDLrR_=s32-c-mo 1x, https://lh3.googleusercontent.com/ogw/AAEL6shhTgbUK8gCKa3E_ZOFS-qwiSmVX1AKUFUDLrR_=s64-c-mo 2x "
# aria-hidden="true" data-noaft=""></span></a>
#
# Code
#
# Insert code cell below
#
# Ctrl+M B
#
# Text
#
# Add text cell
#
# <span class="collapsed-options"> </span> <span class="flex"></span>
# <span class="collapsed-options"> <span class="colab-separator"></span>
# </span> <span class="colab-separator"></span>
#
# Toggle header visibility
#
# <span class="colab-tab-title">Notebook</span>
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# # EXPLORATORY DATA ANALYSIS
#
# ↳ 38 cells hidden
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df = pd.read_csv('/content/train.csv')
# ```
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df.info()
# ```
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 3198 entries, 0 to 3197
#     Data columns (total 19 columns):
#      #   Column                 Non-Null Count  Dtype
#     ---  ------                 --------------  -----
#      0   Video_id               3198 non-null   object
#      1   category_id            3192 non-null   object
#      2   channel_title          3195 non-null   object
#      3   subscriber             3175 non-null   float64
#      4   title                  3195 non-null   object
#      5   tags                   3046 non-null   object
#      6   description            3133 non-null   object
#      7   Trend_day_count        3197 non-null   float64
#      8   Tag_count              3197 non-null   object
#      9   Trend_tag_count        3197 non-null   object
#      10  comment_count          3198 non-null   object
#      11  comment_disabled       3198 non-null   object
#      12  like dislike disabled  3198 non-null   object
#      13  likes                  3198 non-null   object
#      14  dislike                3198 non-null   object
#      15  tag appered in title   3197 non-null   object
#      16  views                  3198 non-null   object
#      17  Unnamed: 17            1 non-null      float64
#      18  Unnamed: 18            1 non-null      object
#     dtypes: float64(3), object(16)
#     memory usage: 474.8+ KB
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **DELETING THE COLUMNS WITH MORE NUMBER OF NULL VALUES**
#
# ↳ 0 cells hidden
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2 = df.drop(['Unnamed: 17', 'Unnamed: 18'], axis =1)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.info()
# ```
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 3198 entries, 0 to 3197
#     Data columns (total 17 columns):
#      #   Column                 Non-Null Count  Dtype
#     ---  ------                 --------------  -----
#      0   Video_id               3198 non-null   object
#      1   category_id            3192 non-null   object
#      2   channel_title          3195 non-null   object
#      3   subscriber             3175 non-null   float64
#      4   title                  3195 non-null   object
#      5   tags                   3046 non-null   object
#      6   description            3133 non-null   object
#      7   Trend_day_count        3197 non-null   float64
#      8   Tag_count              3197 non-null   object
#      9   Trend_tag_count        3197 non-null   object
#      10  comment_count          3198 non-null   object
#      11  comment_disabled       3198 non-null   object
#      12  like dislike disabled  3198 non-null   object
#      13  likes                  3198 non-null   object
#      14  dislike                3198 non-null   object
#      15  tag appered in title   3197 non-null   object
#      16  views                  3198 non-null   object
#     dtypes: float64(2), object(15)
#     memory usage: 424.9+ KB
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **STATISTICAL DESCRIPTION OF THE DATA**
#
# ↳ 0 cells hidden
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.describe()
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **FILLING THE ROWS WITH THE NULL VALUES**
#
# ↳ 0 cells hidden
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.fillna(0)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.info()
# ```
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 3198 entries, 0 to 3197
#     Data columns (total 17 columns):
#      #   Column                 Non-Null Count  Dtype
#     ---  ------                 --------------  -----
#      0   Video_id               3198 non-null   object
#      1   category_id            3192 non-null   object
#      2   channel_title          3195 non-null   object
#      3   subscriber             3175 non-null   float64
#      4   title                  3195 non-null   object
#      5   tags                   3046 non-null   object
#      6   description            3133 non-null   object
#      7   Trend_day_count        3197 non-null   float64
#      8   Tag_count              3197 non-null   object
#      9   Trend_tag_count        3197 non-null   object
#      10  comment_count          3198 non-null   object
#      11  comment_disabled       3198 non-null   object
#      12  like dislike disabled  3198 non-null   object
#      13  likes                  3198 non-null   object
#      14  dislike                3198 non-null   object
#      15  tag appered in title   3197 non-null   object
#      16  views                  3198 non-null   object
#     dtypes: float64(2), object(15)
#     memory usage: 424.9+ KB
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2 = df2.fillna(0)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.info()
# ```
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 3198 entries, 0 to 3197
#     Data columns (total 17 columns):
#      #   Column                 Non-Null Count  Dtype
#     ---  ------                 --------------  -----
#      0   Video_id               3198 non-null   object
#      1   category_id            3192 non-null   object
#      2   channel_title          3195 non-null   object
#      3   subscriber             3175 non-null   float64
#      4   title                  3195 non-null   object
#      5   tags                   3046 non-null   object
#      6   description            3133 non-null   object
#      7   Trend_day_count        3197 non-null   float64
#      8   Tag_count              3197 non-null   object
#      9   Trend_tag_count        3197 non-null   object
#      10  comment_count          3198 non-null   object
#      11  comment_disabled       3198 non-null   object
#      12  like dislike disabled  3198 non-null   object
#      13  likes                  3198 non-null   object
#      14  dislike                3198 non-null   object
#      15  tag appered in title   3197 non-null   object
#      16  views                  3198 non-null   object
#     dtypes: float64(2), object(15)
#     memory usage: 424.9+ KB
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **CHANGING DATA TYPES FOR NUMERIC DATA**
#
# ↳ 0 cells hidden
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2['Trend_day_count']= df2['Trend_day_count'].astype(float)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2['dislike']= pd.to_numeric(df2['dislike'], errors = 'coerce')
# df2['comment_count']= pd.to_numeric(df2['comment_count'], errors = 'coerce')
# df2['Trend_tag_count']= pd.to_numeric(df2['Trend_tag_count'], errors = 'coerce')
# df2['Tag_count']= pd.to_numeric(df2['Tag_count'], errors = 'coerce')
# df2['category_id']= pd.to_numeric(df2['category_id'], errors = 'coerce')
# df2['likes']= pd.to_numeric(df2['likes'], errors = 'coerce')
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2 = df2.fillna(0)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.info()
# ```
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 3198 entries, 0 to 3197
#     Data columns (total 17 columns):
#      #   Column                 Non-Null Count  Dtype
#     ---  ------                 --------------  -----
#      0   Video_id               3198 non-null   object
#      1   category_id            3198 non-null   float64
#      2   channel_title          3198 non-null   object
#      3   subscriber             3198 non-null   float64
#      4   title                  3198 non-null   object
#      5   tags                   3198 non-null   object
#      6   description            3198 non-null   object
#      7   Trend_day_count        3198 non-null   float64
#      8   Tag_count              3198 non-null   float64
#      9   Trend_tag_count        3198 non-null   float64
#      10  comment_count          3198 non-null   float64
#      11  comment_disabled       3198 non-null   bool
#      12  like dislike disabled  3198 non-null   bool
#      13  likes                  3198 non-null   float64
#      14  dislike                3198 non-null   float64
#      15  tag appered in title   3198 non-null   bool
#      16  views                  3198 non-null   object
#     dtypes: bool(3), float64(8), object(6)
#     memory usage: 359.3+ KB
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2['like dislike disabled']= df2['like dislike disabled'].astype(bool)
# df2['comment_disabled']= df2['comment_disabled'].astype(bool)
# df2['tag appered in title']= df2['tag appered in title'].astype(bool)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.fillna(0)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# df2.info()
# ```
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 3198 entries, 0 to 3197
#     Data columns (total 17 columns):
#      #   Column                 Non-Null Count  Dtype
#     ---  ------                 --------------  -----
#      0   Video_id               3198 non-null   object
#      1   category_id            3198 non-null   float64
#      2   channel_title          3198 non-null   object
#      3   subscriber             3198 non-null   float64
#      4   title                  3198 non-null   object
#      5   tags                   3198 non-null   object
#      6   description            3198 non-null   object
#      7   Trend_day_count        3198 non-null   float64
#      8   Tag_count              3198 non-null   float64
#      9   Trend_tag_count        3198 non-null   float64
#      10  comment_count          3198 non-null   float64
#      11  comment_disabled       3198 non-null   bool
#      12  like dislike disabled  3198 non-null   bool
#      13  likes                  3198 non-null   float64
#      14  dislike                3198 non-null   float64
#      15  tag appered in title   3198 non-null   bool
#      16  views                  3198 non-null   object
#     dtypes: bool(3), float64(8), object(6)
#     memory usage: 359.3+ KB
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **visualization**
#
# ↳ 0 cells hidden
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.boxplot(df2['subscriber'])
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.distplot(df2['dislike'])
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.boxplot(df2['likes'])
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.catplot(x="comment_count",y="comment_disabled",data=df2,kind="bar",height=4)
# ```
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# <span class="mtk1">sns.catplot(x=</span><span
# class="mtk26">"Trend_tag_count"</span><span class="mtk1">,y=</span><span
# class="mtk26">"Tag_count"</span><span
# class="mtk1">,data=df2,kind=</span><span class="mtk26">"bar"</span><span
# class="mtk1">,height=</span><span class="mtk12">4</span><span
# class="mtk1">)</span>
#
# Enter to Rename, Shift+Enter to Preview
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# <span class="mtk1">sns.barplot(x= df2\[</span><span
# class="mtk26">'Video_id'</span><span
# class="mtk1">\].head(), y= df2\[</span><span
# class="mtk26">'Trend_day_count'</span><span
# class="mtk1">\].head())</span>
#
# <span class="mtk1">sns.lineplot(x= df2\[</span><span
# class="mtk26">'Video_id'</span><span
# class="mtk1">\].head(), y= df2\[</span><span
# class="mtk26">'Trend_day_count'</span><span
# class="mtk1">\].head())</span>
#
# Enter to Rename, Shift+Enter to Preview
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.countplot(x ='like dislike disabled', data=df2)
# ```
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.countplot(x ='comment_disabled', data=df2)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.countplot(x ='tag appered in title', data=df2)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **VIOLIN PLOT**
#
# ↳ 0 cells hidden
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.violinplot(df2.Trend_day_count,df2.Trend_tag_count)
# ```
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **REGRESSION PLOT**
#
# ↳ 0 cells hidden
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.regplot(x = df2.Trend_day_count, y = df2.Trend_tag_count)
# ```
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# **HEAT MAP**
#
# ↳ 0 cells hidden
#
# Code Text
#
# ------------------------------------------------------------------------
#
# <span class="imported-info-area"></span>
#
# ``` lazy-virtualized
# ```
#
# ``` monaco-colorized
# sns.heatmap(data = df2.corr(), annot = True, linewidth=0.5,cmap = 'Blues', cbar = True,vmin=-1, vmax=1)
# ```
#
# ------------------------------------------------------------------------
#
# <a
# href="https://colab.research.google.com/signup?utm_source=footer&amp;utm_medium=link&amp;utm_campaign=footer_links"
# target="_blank">Colab paid products</a> -
# <a href="https://colab.research.google.com/cancel-subscription"
# target="_blank">Cancel contracts here</a>
#
# Locate in Drive
#
# Open in playground mode
#
# New notebook
#
# Open notebook<span class="goog-menuitem-accel">Ctrl+O</span>
#
# Upload notebook
#
# Rename
#
# Move
#
# Move to trash
#
# Save a copy in Drive
#
# Save a copy as a GitHub Gist
#
# Save a copy in GitHub
#
# Save<span class="goog-menuitem-accel">Ctrl+S</span>
#
# Save and pin revision<span class="goog-menuitem-accel">Ctrl+M S</span>
#
# Revision history
#
# Download <span class="goog-submenu-arrow"
# style="user-select: none;">►</span>
#
# Print<span class="goog-menuitem-accel">Ctrl+P</span>
#
# Download .ipynb
#
# Download .py
#
# Undo
#
# Redo
#
# Select all cells
#
# Cut cell or selection
#
# Copy cell or selection
#
# Paste
#
# Delete selected cells
#
# Find and replace
#
# Find next
#
# Find previous
#
# Notebook settings
#
# Clear all outputs
#
# Table of contents
#
# Notebook info
#
# Executed code history
#
# Comments sidebar
#
# Collapse sections
#
# Expand sections
#
# Save collapsed section layout
#
# Show/hide code
#
# Show/hide output
#
# Focus next tab
#
# Focus previous tab
#
# Move tab to next pane
#
# Move tab to previous pane
#
# Code cell
#
# Text cell
#
# Section header cell
#
# Scratch code cell
#
# Code snippets
#
# Add a form field
#
# Run all
#
# Run before
#
# Run the focused cell
#
# Run selection
#
# Run after
#
# Interrupt execution
#
# Restart runtime
#
# Restart and run all
#
# Disconnect and delete runtime
#
# Change runtime type
#
# Manage sessions
#
# View runtime logs
#
# Command palette
#
# Settings
#
# Keyboard shortcuts
#
# Diff notebooks
#
# Frequently asked questions
#
# View release notes
#
# Search code snippets
#
# Report a bug
#
# Report Drive abuse
#
# Send feedback
#
# Add a comment
